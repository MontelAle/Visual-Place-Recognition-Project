# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
# !git clone --recursive https://github.com/MontelAle/Visual-Place-Recognition-Project.git

# %%
# %cd Visual-Place-Recognition-Project/image-matching-models

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -e .

# %%
# !pip install faiss-cpu

# %%
# %cd ..

# %% [markdown]
# ## Download Datasets

# %%
# !python download_datasets.py

# %% [markdown]
# # TASK 2

# %% [markdown]
# ## Get predictions for your model and dataset

# %% [markdown]
# ### Netvlad

# %%
# Metodo NetVLAD con backbone VGG16 descrittore con dimensione 4096 metrica distanza L2
# !python matching_recall.py \
--method=netvlad --backbone=VGG16 --descriptors-dimension=4096

# %% [markdown]
# ### Mixvpr

# %%
# Metodo MixVPR backbone ResNet50 metrica L2
# !python matching_recall.py \
--method=mixvpr --backbone=ResNet50 --descriptors-dimension=4096

# %% [markdown]
# ### Megaloc

# %%
# Metodo MegaLOC backbone Dinov2 metrica L2
# !python matching_recall.py \
--method=megaloc --backbone=Dinov2 --descriptors-dimension=8448

# %% [markdown]
# ### Cosplace

# %%
# Metodo Cosplace backbone ResNet50 metrica L2
# !python matching_recall.py \
--method=cosplace --backbone=ResNet50 --descriptors-dimension=2048
